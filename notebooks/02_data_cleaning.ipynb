# %% [markdown]
# # 🧹 02 - Data Cleaning and Preparation

# %%
import pandas as pd
import sys
sys.path.append('..')
from src.data_loader import load_world_bank_data
from src.data_cleaner import clean_economic_data, get_summary_stats

df = load_world_bank_data()

# %%
# Clean the data
df_clean = clean_economic_data(df)
df_clean.head()

# %%
# Summary statistics
stats = get_summary_stats(df_clean)
for key, value in stats.items():
    print(f"{key}: {value}")
